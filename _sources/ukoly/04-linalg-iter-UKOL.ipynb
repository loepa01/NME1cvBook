# %% [markdown]
# (ukol3)=
# # Zápočtový úkol 3

# %% [markdown]
# <div style="margin-top: 25px; margin-bottom: 25px; padding-top: 0px; padding-bottom: 0px; padding-left: 0px; padding-right: 0px; border-radius: 4px; border-color: #E0B32C; border-right-width: 1px; border-top-width: 1px; border-bottom-width: 1px; border-left-width: 3px; border-style: solid">
# <div style="background: #FFF3CD; color: #000000; padding-left: 20px; padding-top: 10px; padding-bottom: 10px; border-radius: 1px 3px 0px 0px; font-weight: 600">Úkol - zápočet 3</div>
# <div style="padding-left: 20px; padding-right: 20px; padding-top: 0px; padding-bottom: 0px; border-radius: 0px 0px 3px 3px">
# <p>
#
# Implementujte metodu částečného problému vlastních čísel (viz [cvičení](cast_vl_cis)). Aplikujte tuto metodu rekurzivně tak, pro nalezení všech vlastních čísel matice. Otestujte metodu na náhodně vygenerované **symetrické**, **pozitivně definitní** matici o velikosti $n$. Ověřte přesnost pomocí knihovní funkce `np.linalg.eig()`, která vrací vlastní čísla i vektory. Určete relativní chyby jednotlivých vlastních čísel s využitím přesné hodnoty. Pro jaké $n$ již dochází k významné ztrátě přesnosti? Proč?
# </p>
# </div>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
## DOPLŇTE ##
